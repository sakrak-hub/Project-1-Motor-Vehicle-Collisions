# %%
import pandas as pd
import psycopg2
import dlt
from dlt.sources.helpers.rest_client import RESTClient
from dlt.sources.helpers.rest_client.paginators import OffsetPaginator
import requests
from pathlib import Path
import json
import io

# %%
mvc_crashes = "https://data.cityofnewyork.us/resource/h9gi-nx95.json"
mvc_vehicles = "https://data.cityofnewyork.us/resource/bm4k-52h4.json"
mvc_persons = "https://data.cityofnewyork.us/resource/f55k-p6yu.json"
src_dict = {
    mvc_crashes:"mvc_crashes", 
    mvc_vehicles:"mvc_vehicles", 
    mvc_persons:"mvc_persons"}

# %%
def load_from_source(src, offset, max_offset):
    # Initialize the REST client
    client = RESTClient(
        base_url=src,
        paginator=OffsetPaginator(
            limit=1000,
            offset=offset,
            maximum_offset=max_offset,
            limit_param="$limit", 
            offset_param="$offset",
            total_path=None
        )
        )

    for page in client.paginate():
        yield page

# for page in load_from_source():
#     # Convert the page to a DataFrame
#     print(page)

# %%
def add_to_pipeline(data,name):

    # Initialize the pipeline
    pipeline = dlt.pipeline(destination="postgres", dataset_name="motor_vehicle_collisions")

    # Run the pipeline
    load_info = pipeline.run(data,table_name=name, write_disposition="append", loader_file_format="csv")

    # Print the load info
    print(load_info)
    # Print the number of rows loaded

# %%
def add_to_pipeline_two(data,name):

    # Initialize the pipeline
    pipeline = dlt.pipeline(destination="postgres", dataset_name="motor_vehicle_collisions")

    # Run the pipeline
    load_info = pipeline.run(data,table_name=name, write_disposition="append")

    # Print the load info
    print(load_info)
    # Print the number of rows loaded

# %%
for source in src_dict.keys():
        page_max_offset = 50000
        page_offset = 0
        page = 1
        name = src_dict[source]
        response = requests.get(f"{source}?$limit=1000&$offset={page_max_offset}")
        while len(response.json()) != 0:
            print(f"Loading page {page} from {name} with offset {page_offset}")
            data = load_from_source(source, page_offset, page_max_offset)
            add_to_pipeline_two(data,name)
            page_offset += 50000
            page += 1
            response = requests.get(f"{source}?$limit=1000&$offset={(page_offset+1000)}")
            page_max_offset +=50000
# Out:
# Loading page 1 from mvc_crashes with offset 0
# Pipeline dlt_ipykernel_launcher load step completed in 2.07 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748231800.1802902 is LOADED and contains no failed jobs
# Loading page 2 from mvc_crashes with offset 50000
# Pipeline dlt_ipykernel_launcher load step completed in 1.70 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748231835.720766 is LOADED and contains no failed jobs
# Loading page 3 from mvc_crashes with offset 100000
# Pipeline dlt_ipykernel_launcher load step completed in 2.30 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748231872.2831163 is LOADED and contains no failed jobs
# Loading page 4 from mvc_crashes with offset 150000
# Pipeline dlt_ipykernel_launcher load step completed in 1.99 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748231912.7300205 is LOADED and contains no failed jobs
# Loading page 5 from mvc_crashes with offset 200000
# Pipeline dlt_ipykernel_launcher load step completed in 2.04 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748231955.575704 is LOADED and contains no failed jobs
# Loading page 6 from mvc_crashes with offset 250000
# Pipeline dlt_ipykernel_launcher load step completed in 1.83 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748232003.916219 is LOADED and contains no failed jobs
# Loading page 7 from mvc_crashes with offset 300000
# Pipeline dlt_ipykernel_launcher load step completed in 0.24 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748232057.5506015 is LOADED and contains no failed jobs
# Loading page 8 from mvc_crashes with offset 350000
# Pipeline dlt_ipykernel_launcher load step completed in 3.17 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748232110.1201012 is LOADED and contains no failed jobs
# Loading page 9 from mvc_crashes with offset 400000
# Pipeline dlt_ipykernel_launcher load step completed in 2.17 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748232168.70988 is LOADED and contains no failed jobs
# Loading page 10 from mvc_crashes with offset 450000
# Pipeline dlt_ipykernel_launcher load step completed in 2.17 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748232231.1874676 is LOADED and contains no failed jobs
# Loading page 11 from mvc_crashes with offset 500000
# Pipeline dlt_ipykernel_launcher load step completed in 2.03 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748232289.073027 is LOADED and contains no failed jobs
# Loading page 12 from mvc_crashes with offset 550000
# Pipeline dlt_ipykernel_launcher load step completed in 1.96 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748232342.2953794 is LOADED and contains no failed jobs
# Loading page 13 from mvc_crashes with offset 600000
# Pipeline dlt_ipykernel_launcher load step completed in 1.83 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748232399.3481033 is LOADED and contains no failed jobs
# Loading page 14 from mvc_crashes with offset 650000
# Pipeline dlt_ipykernel_launcher load step completed in 1.84 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748232462.8037212 is LOADED and contains no failed jobs
# Loading page 15 from mvc_crashes with offset 700000
# Pipeline dlt_ipykernel_launcher load step completed in 1.87 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748232519.3047261 is LOADED and contains no failed jobs
# Loading page 16 from mvc_crashes with offset 750000
# Pipeline dlt_ipykernel_launcher load step completed in 1.58 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748232576.6025004 is LOADED and contains no failed jobs
# Loading page 17 from mvc_crashes with offset 800000
# Pipeline dlt_ipykernel_launcher load step completed in 0.03 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748232633.9482493 is LOADED and contains no failed jobs
# Loading page 18 from mvc_crashes with offset 850000
# Pipeline dlt_ipykernel_launcher load step completed in 1.63 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748232693.8039892 is LOADED and contains no failed jobs
# Loading page 19 from mvc_crashes with offset 900000
# Pipeline dlt_ipykernel_launcher load step completed in 1.80 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748232754.195209 is LOADED and contains no failed jobs
# Loading page 20 from mvc_crashes with offset 950000
# Pipeline dlt_ipykernel_launcher load step completed in 1.90 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748232814.505489 is LOADED and contains no failed jobs
# Loading page 21 from mvc_crashes with offset 1000000
# Pipeline dlt_ipykernel_launcher load step completed in 1.70 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748232875.5600955 is LOADED and contains no failed jobs
# Loading page 22 from mvc_crashes with offset 1050000
# Pipeline dlt_ipykernel_launcher load step completed in 1.71 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748232937.3113313 is LOADED and contains no failed jobs
# Loading page 23 from mvc_crashes with offset 1100000
# Pipeline dlt_ipykernel_launcher load step completed in 1.72 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748232999.07355 is LOADED and contains no failed jobs
# Loading page 24 from mvc_crashes with offset 1150000
# Pipeline dlt_ipykernel_launcher load step completed in 1.73 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748233061.1774793 is LOADED and contains no failed jobs
# Loading page 25 from mvc_crashes with offset 1200000
# Pipeline dlt_ipykernel_launcher load step completed in 0.50 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748233124.0101364 is LOADED and contains no failed jobs
# Loading page 26 from mvc_crashes with offset 1250000
# Pipeline dlt_ipykernel_launcher load step completed in 0.63 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748233186.232081 is LOADED and contains no failed jobs
# Loading page 27 from mvc_crashes with offset 1300000
# Pipeline dlt_ipykernel_launcher load step completed in 1.95 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748233248.1709394 is LOADED and contains no failed jobs
# Loading page 28 from mvc_crashes with offset 1350000
# Pipeline dlt_ipykernel_launcher load step completed in 1.89 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748233312.2097242 is LOADED and contains no failed jobs
# Loading page 29 from mvc_crashes with offset 1400000
# Pipeline dlt_ipykernel_launcher load step completed in 2.09 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748233378.2185905 is LOADED and contains no failed jobs
# Loading page 30 from mvc_crashes with offset 1450000
# Pipeline dlt_ipykernel_launcher load step completed in 1.83 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748233450.1430123 is LOADED and contains no failed jobs
# Loading page 31 from mvc_crashes with offset 1500000
# Pipeline dlt_ipykernel_launcher load step completed in 0.48 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748233520.152867 is LOADED and contains no failed jobs
# Loading page 32 from mvc_crashes with offset 1550000
# Pipeline dlt_ipykernel_launcher load step completed in 2.03 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748233586.23046 is LOADED and contains no failed jobs
# Loading page 33 from mvc_crashes with offset 1600000
# Pipeline dlt_ipykernel_launcher load step completed in 2.19 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748233653.6505487 is LOADED and contains no failed jobs
# Loading page 34 from mvc_crashes with offset 1650000
# Pipeline dlt_ipykernel_launcher load step completed in 2.75 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748233720.4792447 is LOADED and contains no failed jobs
# Loading page 35 from mvc_crashes with offset 1700000
# Pipeline dlt_ipykernel_launcher load step completed in 1.91 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748233788.7089334 is LOADED and contains no failed jobs
# Loading page 36 from mvc_crashes with offset 1750000
# Pipeline dlt_ipykernel_launcher load step completed in 1.77 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748233857.0600967 is LOADED and contains no failed jobs
# Loading page 37 from mvc_crashes with offset 1800000
# Pipeline dlt_ipykernel_launcher load step completed in 1.83 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748233926.454692 is LOADED and contains no failed jobs
# Loading page 38 from mvc_crashes with offset 1850000
# Pipeline dlt_ipykernel_launcher load step completed in 1.99 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748234000.1944 is LOADED and contains no failed jobs
# Loading page 39 from mvc_crashes with offset 1900000
# Pipeline dlt_ipykernel_launcher load step completed in 2.23 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748234069.825016 is LOADED and contains no failed jobs
# Loading page 40 from mvc_crashes with offset 1950000
# Pipeline dlt_ipykernel_launcher load step completed in 1.80 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748234141.1754718 is LOADED and contains no failed jobs
# Loading page 41 from mvc_crashes with offset 2000000
# Pipeline dlt_ipykernel_launcher load step completed in 1.94 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748234212.3660913 is LOADED and contains no failed jobs
# Loading page 42 from mvc_crashes with offset 2050000
# Pipeline dlt_ipykernel_launcher load step completed in 0.94 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748234285.1196032 is LOADED and contains no failed jobs
# Loading page 43 from mvc_crashes with offset 2100000
# Pipeline dlt_ipykernel_launcher load step completed in 1.75 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748234354.942098 is LOADED and contains no failed jobs
# Loading page 44 from mvc_crashes with offset 2150000
# Pipeline dlt_ipykernel_launcher load step completed in 1.06 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748234429.365995 is LOADED and contains no failed jobs
# Loading page 1 from mvc_vehicles with offset 0
# Pipeline dlt_ipykernel_launcher load step completed in 0 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748234473.2866616 is LOADED and contains no failed jobs
# Loading page 2 from mvc_vehicles with offset 50000
# Pipeline dlt_ipykernel_launcher load step completed in 1.29 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748234506.7022512 is LOADED and contains no failed jobs
# Loading page 3 from mvc_vehicles with offset 100000
# Pipeline dlt_ipykernel_launcher load step completed in 1.37 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748234539.4145749 is LOADED and contains no failed jobs
# Loading page 4 from mvc_vehicles with offset 150000
# Pipeline dlt_ipykernel_launcher load step completed in 1.45 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748234572.450522 is LOADED and contains no failed jobs
# Loading page 5 from mvc_vehicles with offset 200000
# Pipeline dlt_ipykernel_launcher load step completed in 1.44 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748234606.962272 is LOADED and contains no failed jobs
# Loading page 6 from mvc_vehicles with offset 250000
# Pipeline dlt_ipykernel_launcher load step completed in 1.39 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748234643.1784258 is LOADED and contains no failed jobs
# Loading page 7 from mvc_vehicles with offset 300000
# Pipeline dlt_ipykernel_launcher load step completed in 1.37 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748234683.3632305 is LOADED and contains no failed jobs
# Loading page 8 from mvc_vehicles with offset 350000
# Pipeline dlt_ipykernel_launcher load step completed in 1.40 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748234719.105355 is LOADED and contains no failed jobs
# Loading page 9 from mvc_vehicles with offset 400000
# Pipeline dlt_ipykernel_launcher load step completed in 1.33 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748234756.1399364 is LOADED and contains no failed jobs
# Loading page 10 from mvc_vehicles with offset 450000
# Pipeline dlt_ipykernel_launcher load step completed in 1.33 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748234796.1875029 is LOADED and contains no failed jobs
# Loading page 11 from mvc_vehicles with offset 500000
# Pipeline dlt_ipykernel_launcher load step completed in 1.33 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748234836.9500594 is LOADED and contains no failed jobs
# Loading page 12 from mvc_vehicles with offset 550000
# Pipeline dlt_ipykernel_launcher load step completed in 1.42 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748234878.571851 is LOADED and contains no failed jobs
# Loading page 13 from mvc_vehicles with offset 600000
# Pipeline dlt_ipykernel_launcher load step completed in 1.43 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748234924.7559516 is LOADED and contains no failed jobs
# Loading page 14 from mvc_vehicles with offset 650000
# Pipeline dlt_ipykernel_launcher load step completed in 1.45 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748234970.4546573 is LOADED and contains no failed jobs
# Loading page 15 from mvc_vehicles with offset 700000
# Pipeline dlt_ipykernel_launcher load step completed in 0 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748235013.9629214 is LOADED and contains no failed jobs
# Loading page 16 from mvc_vehicles with offset 750000
# Pipeline dlt_ipykernel_launcher load step completed in 1.41 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748235059.073448 is LOADED and contains no failed jobs
# Loading page 17 from mvc_vehicles with offset 800000
# Pipeline dlt_ipykernel_launcher load step completed in 1.54 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748235104.2419517 is LOADED and contains no failed jobs
# Loading page 18 from mvc_vehicles with offset 850000
# Pipeline dlt_ipykernel_launcher load step completed in 1.62 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748235150.6211693 is LOADED and contains no failed jobs
# Loading page 19 from mvc_vehicles with offset 900000
# Pipeline dlt_ipykernel_launcher load step completed in 1.76 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748235198.3818724 is LOADED and contains no failed jobs
# Loading page 20 from mvc_vehicles with offset 950000
# Pipeline dlt_ipykernel_launcher load step completed in 1.58 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748235248.097981 is LOADED and contains no failed jobs
# Loading page 21 from mvc_vehicles with offset 1000000
# Pipeline dlt_ipykernel_launcher load step completed in 1.54 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748235302.465323 is LOADED and contains no failed jobs
# Loading page 22 from mvc_vehicles with offset 1050000
# Pipeline dlt_ipykernel_launcher load step completed in 1.33 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748235354.9492862 is LOADED and contains no failed jobs
# Loading page 23 from mvc_vehicles with offset 1100000
# Pipeline dlt_ipykernel_launcher load step completed in 1.37 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748235406.1042438 is LOADED and contains no failed jobs
# Loading page 24 from mvc_vehicles with offset 1150000
# Pipeline dlt_ipykernel_launcher load step completed in 1.44 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748235457.719734 is LOADED and contains no failed jobs
# Loading page 25 from mvc_vehicles with offset 1200000
# Pipeline dlt_ipykernel_launcher load step completed in 1.62 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748235504.747312 is LOADED and contains no failed jobs
# Loading page 26 from mvc_vehicles with offset 1250000
# Pipeline dlt_ipykernel_launcher load step completed in 1.38 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748235556.0722337 is LOADED and contains no failed jobs
# Loading page 27 from mvc_vehicles with offset 1300000
# Pipeline dlt_ipykernel_launcher load step completed in 1.33 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748235608.1118827 is LOADED and contains no failed jobs
# Loading page 28 from mvc_vehicles with offset 1350000
# Pipeline dlt_ipykernel_launcher load step completed in 1.34 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748235662.1050923 is LOADED and contains no failed jobs
# Loading page 29 from mvc_vehicles with offset 1400000
# Pipeline dlt_ipykernel_launcher load step completed in 1.35 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748235715.6209946 is LOADED and contains no failed jobs
# Loading page 30 from mvc_vehicles with offset 1450000
# Pipeline dlt_ipykernel_launcher load step completed in 1.40 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748235770.2897823 is LOADED and contains no failed jobs
# Loading page 31 from mvc_vehicles with offset 1500000
# Pipeline dlt_ipykernel_launcher load step completed in 1.94 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748235825.3405323 is LOADED and contains no failed jobs
# Loading page 32 from mvc_vehicles with offset 1550000
# Pipeline dlt_ipykernel_launcher load step completed in 1.40 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748235882.7819633 is LOADED and contains no failed jobs
# Loading page 33 from mvc_vehicles with offset 1600000
# Pipeline dlt_ipykernel_launcher load step completed in 1.57 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748235938.354687 is LOADED and contains no failed jobs
# Loading page 34 from mvc_vehicles with offset 1650000
# Pipeline dlt_ipykernel_launcher load step completed in 1.33 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748235995.7196927 is LOADED and contains no failed jobs
# Loading page 35 from mvc_vehicles with offset 1700000
# Pipeline dlt_ipykernel_launcher load step completed in 1.34 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748236052.8657346 is LOADED and contains no failed jobs
# Loading page 36 from mvc_vehicles with offset 1750000
# Pipeline dlt_ipykernel_launcher load step completed in 1.55 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748236109.521669 is LOADED and contains no failed jobs
# Loading page 37 from mvc_vehicles with offset 1800000
# Pipeline dlt_ipykernel_launcher load step completed in 0 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748236167.9900217 is LOADED and contains no failed jobs
# Loading page 38 from mvc_vehicles with offset 1850000
# Pipeline dlt_ipykernel_launcher load step completed in 1.41 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748236226.7614002 is LOADED and contains no failed jobs
# Loading page 39 from mvc_vehicles with offset 1900000
# Pipeline dlt_ipykernel_launcher load step completed in 1.73 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748236286.7799013 is LOADED and contains no failed jobs
# Loading page 40 from mvc_vehicles with offset 1950000
# Pipeline dlt_ipykernel_launcher load step completed in 1.60 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748236352.1286433 is LOADED and contains no failed jobs
# Loading page 41 from mvc_vehicles with offset 2000000
# Pipeline dlt_ipykernel_launcher load step completed in 1.82 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748236418.2626853 is LOADED and contains no failed jobs
# Loading page 42 from mvc_vehicles with offset 2050000
# Pipeline dlt_ipykernel_launcher load step completed in 1.67 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748236484.6877112 is LOADED and contains no failed jobs
# Loading page 43 from mvc_vehicles with offset 2100000
# Pipeline dlt_ipykernel_launcher load step completed in 1.69 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748236552.2386136 is LOADED and contains no failed jobs
# Loading page 44 from mvc_vehicles with offset 2150000
# Pipeline dlt_ipykernel_launcher load step completed in 1.76 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748236622.375063 is LOADED and contains no failed jobs
# Loading page 45 from mvc_vehicles with offset 2200000
# Pipeline dlt_ipykernel_launcher load step completed in 2.98 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748236689.4116867 is LOADED and contains no failed jobs
# Loading page 46 from mvc_vehicles with offset 2250000
# Pipeline dlt_ipykernel_launcher load step completed in 1.54 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748236760.682831 is LOADED and contains no failed jobs
# Loading page 47 from mvc_vehicles with offset 2300000
# Pipeline dlt_ipykernel_launcher load step completed in 1.64 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748236829.8941529 is LOADED and contains no failed jobs
# Loading page 48 from mvc_vehicles with offset 2350000
# Pipeline dlt_ipykernel_launcher load step completed in 1.62 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748236899.1971443 is LOADED and contains no failed jobs
# Loading page 49 from mvc_vehicles with offset 2400000
# Pipeline dlt_ipykernel_launcher load step completed in 1.93 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748236968.4400554 is LOADED and contains no failed jobs
# Loading page 50 from mvc_vehicles with offset 2450000
# Pipeline dlt_ipykernel_launcher load step completed in 1.74 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748237040.7701979 is LOADED and contains no failed jobs
# Loading page 51 from mvc_vehicles with offset 2500000
# Pipeline dlt_ipykernel_launcher load step completed in 1.87 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748237112.0575104 is LOADED and contains no failed jobs
# Loading page 52 from mvc_vehicles with offset 2550000
# Pipeline dlt_ipykernel_launcher load step completed in 1.90 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748237183.0413492 is LOADED and contains no failed jobs
# Loading page 53 from mvc_vehicles with offset 2600000
# Pipeline dlt_ipykernel_launcher load step completed in 2.00 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748237256.7457116 is LOADED and contains no failed jobs
# Loading page 54 from mvc_vehicles with offset 2650000
# Pipeline dlt_ipykernel_launcher load step completed in 2.56 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748237330.5800793 is LOADED and contains no failed jobs
# Loading page 55 from mvc_vehicles with offset 2700000
# Pipeline dlt_ipykernel_launcher load step completed in 2.15 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748237405.3704958 is LOADED and contains no failed jobs
# Loading page 56 from mvc_vehicles with offset 2750000
# Pipeline dlt_ipykernel_launcher load step completed in 1.68 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748237480.923946 is LOADED and contains no failed jobs
# Loading page 57 from mvc_vehicles with offset 2800000
# Pipeline dlt_ipykernel_launcher load step completed in 1.90 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748237556.0668933 is LOADED and contains no failed jobs
# Loading page 58 from mvc_vehicles with offset 2850000
# Pipeline dlt_ipykernel_launcher load step completed in 2.31 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748237632.221791 is LOADED and contains no failed jobs
# Loading page 59 from mvc_vehicles with offset 2900000
# Pipeline dlt_ipykernel_launcher load step completed in 1.94 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748237711.9232237 is LOADED and contains no failed jobs
# Loading page 60 from mvc_vehicles with offset 2950000
# Pipeline dlt_ipykernel_launcher load step completed in 2.02 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748237792.9105024 is LOADED and contains no failed jobs
# Loading page 61 from mvc_vehicles with offset 3000000
# Pipeline dlt_ipykernel_launcher load step completed in 1.92 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748237875.1962192 is LOADED and contains no failed jobs
# Loading page 62 from mvc_vehicles with offset 3050000
# Pipeline dlt_ipykernel_launcher load step completed in 0.65 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748237957.8399816 is LOADED and contains no failed jobs
# Loading page 63 from mvc_vehicles with offset 3100000
# Pipeline dlt_ipykernel_launcher load step completed in 2.10 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748238041.8109555 is LOADED and contains no failed jobs
# Loading page 64 from mvc_vehicles with offset 3150000
# Pipeline dlt_ipykernel_launcher load step completed in 1.78 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748238127.697806 is LOADED and contains no failed jobs
# Loading page 65 from mvc_vehicles with offset 3200000
# Pipeline dlt_ipykernel_launcher load step completed in 2.12 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748238212.140636 is LOADED and contains no failed jobs
# Loading page 66 from mvc_vehicles with offset 3250000
# Pipeline dlt_ipykernel_launcher load step completed in 1.78 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748238297.9536674 is LOADED and contains no failed jobs
# Loading page 67 from mvc_vehicles with offset 3300000
# Pipeline dlt_ipykernel_launcher load step completed in 0.30 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748238384.7409465 is LOADED and contains no failed jobs
# Loading page 68 from mvc_vehicles with offset 3350000
# Pipeline dlt_ipykernel_launcher load step completed in 1.91 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748238471.418437 is LOADED and contains no failed jobs
# Loading page 69 from mvc_vehicles with offset 3400000
# Pipeline dlt_ipykernel_launcher load step completed in 2.01 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748238560.953601 is LOADED and contains no failed jobs
# Loading page 70 from mvc_vehicles with offset 3450000
# Pipeline dlt_ipykernel_launcher load step completed in 2.17 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748238649.8738132 is LOADED and contains no failed jobs
# Loading page 71 from mvc_vehicles with offset 3500000
# Pipeline dlt_ipykernel_launcher load step completed in 2.30 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748238739.7101548 is LOADED and contains no failed jobs
# Loading page 72 from mvc_vehicles with offset 3550000
# Pipeline dlt_ipykernel_launcher load step completed in 3.99 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748238829.419122 is LOADED and contains no failed jobs
# Loading page 73 from mvc_vehicles with offset 3600000
# Pipeline dlt_ipykernel_launcher load step completed in 2.17 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748238921.6541803 is LOADED and contains no failed jobs
# Loading page 74 from mvc_vehicles with offset 3650000
# Pipeline dlt_ipykernel_launcher load step completed in 2.33 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748239013.502186 is LOADED and contains no failed jobs
# Loading page 75 from mvc_vehicles with offset 3700000
# Pipeline dlt_ipykernel_launcher load step completed in 2.67 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748239106.3947804 is LOADED and contains no failed jobs
# Loading page 76 from mvc_vehicles with offset 3750000
# Pipeline dlt_ipykernel_launcher load step completed in 2.68 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748239199.028252 is LOADED and contains no failed jobs
# Loading page 77 from mvc_vehicles with offset 3800000
# Pipeline dlt_ipykernel_launcher load step completed in 2.29 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748239293.2216806 is LOADED and contains no failed jobs
# Loading page 78 from mvc_vehicles with offset 3850000
# Pipeline dlt_ipykernel_launcher load step completed in 2.00 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748239386.0531788 is LOADED and contains no failed jobs
# Loading page 79 from mvc_vehicles with offset 3900000
# Pipeline dlt_ipykernel_launcher load step completed in 2.40 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748239479.7156248 is LOADED and contains no failed jobs
# Loading page 80 from mvc_vehicles with offset 3950000
# Pipeline dlt_ipykernel_launcher load step completed in 2.21 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# ...
# Load package 1748244849.9784331 is LOADED and contains no failed jobs
# Loading page 74 from mvc_persons with offset 3650000
# Pipeline dlt_ipykernel_launcher load step completed in 1.68 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748244932.9446187 is LOADED and contains no failed jobs
# Loading page 75 from mvc_persons with offset 3700000
# Pipeline dlt_ipykernel_launcher load step completed in 1.71 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748245019.807711 is LOADED and contains no failed jobs
# Loading page 76 from mvc_persons with offset 3750000
# Pipeline dlt_ipykernel_launcher load step completed in 2.30 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748245108.3973935 is LOADED and contains no failed jobs
# Loading page 77 from mvc_persons with offset 3800000
# Pipeline dlt_ipykernel_launcher load step completed in 1.51 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748245196.8537226 is LOADED and contains no failed jobs
# Loading page 78 from mvc_persons with offset 3850000
# Pipeline dlt_ipykernel_launcher load step completed in 1.76 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748245286.0207121 is LOADED and contains no failed jobs
# Loading page 79 from mvc_persons with offset 3900000
# Pipeline dlt_ipykernel_launcher load step completed in 1.92 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748245375.7367876 is LOADED and contains no failed jobs
# Loading page 80 from mvc_persons with offset 3950000
# Pipeline dlt_ipykernel_launcher load step completed in 1.48 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748245465.8299112 is LOADED and contains no failed jobs
# Loading page 81 from mvc_persons with offset 4000000
# Pipeline dlt_ipykernel_launcher load step completed in 1.56 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748245554.7364233 is LOADED and contains no failed jobs
# Loading page 82 from mvc_persons with offset 4050000
# Pipeline dlt_ipykernel_launcher load step completed in 3.96 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748245645.8566928 is LOADED and contains no failed jobs
# Loading page 83 from mvc_persons with offset 4100000
# Pipeline dlt_ipykernel_launcher load step completed in 1.72 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748245739.813643 is LOADED and contains no failed jobs
# Loading page 84 from mvc_persons with offset 4150000
# Pipeline dlt_ipykernel_launcher load step completed in 2.27 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748245829.6071687 is LOADED and contains no failed jobs
# Loading page 85 from mvc_persons with offset 4200000
# Pipeline dlt_ipykernel_launcher load step completed in 1.52 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748245924.262244 is LOADED and contains no failed jobs
# Loading page 86 from mvc_persons with offset 4250000
# Pipeline dlt_ipykernel_launcher load step completed in 2.38 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748246017.7160769 is LOADED and contains no failed jobs
# Loading page 87 from mvc_persons with offset 4300000
# Pipeline dlt_ipykernel_launcher load step completed in 1.76 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748246111.536315 is LOADED and contains no failed jobs
# Loading page 88 from mvc_persons with offset 4350000
# Pipeline dlt_ipykernel_launcher load step completed in 1.76 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748246205.146396 is LOADED and contains no failed jobs
# Loading page 89 from mvc_persons with offset 4400000
# Pipeline dlt_ipykernel_launcher load step completed in 2.54 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748246297.926673 is LOADED and contains no failed jobs
# Loading page 90 from mvc_persons with offset 4450000
# Pipeline dlt_ipykernel_launcher load step completed in 1.77 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748246393.1874268 is LOADED and contains no failed jobs
# Loading page 91 from mvc_persons with offset 4500000
# Pipeline dlt_ipykernel_launcher load step completed in 1.55 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748246488.0064745 is LOADED and contains no failed jobs
# Loading page 92 from mvc_persons with offset 4550000
# Pipeline dlt_ipykernel_launcher load step completed in 1.73 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748246582.9301157 is LOADED and contains no failed jobs
# Loading page 93 from mvc_persons with offset 4600000
# Pipeline dlt_ipykernel_launcher load step completed in 1.55 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748246677.8924954 is LOADED and contains no failed jobs
# Loading page 94 from mvc_persons with offset 4650000
# Pipeline dlt_ipykernel_launcher load step completed in 0.26 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748246773.8380826 is LOADED and contains no failed jobs
# Loading page 95 from mvc_persons with offset 4700000
# Pipeline dlt_ipykernel_launcher load step completed in 2.48 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748246869.5411735 is LOADED and contains no failed jobs
# Loading page 96 from mvc_persons with offset 4750000
# Pipeline dlt_ipykernel_launcher load step completed in 2.07 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748246967.842142 is LOADED and contains no failed jobs
# Loading page 97 from mvc_persons with offset 4800000
# Pipeline dlt_ipykernel_launcher load step completed in 1.99 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748247065.4937477 is LOADED and contains no failed jobs
# Loading page 98 from mvc_persons with offset 4850000
# Pipeline dlt_ipykernel_launcher load step completed in 1.59 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748247163.6953769 is LOADED and contains no failed jobs
# Loading page 99 from mvc_persons with offset 4900000
# Pipeline dlt_ipykernel_launcher load step completed in 1.80 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748247261.0734575 is LOADED and contains no failed jobs
# Loading page 100 from mvc_persons with offset 4950000
# Pipeline dlt_ipykernel_launcher load step completed in 1.85 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748247358.851646 is LOADED and contains no failed jobs
# Loading page 101 from mvc_persons with offset 5000000
# Pipeline dlt_ipykernel_launcher load step completed in 2.96 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748247458.670792 is LOADED and contains no failed jobs
# Loading page 102 from mvc_persons with offset 5050000
# Pipeline dlt_ipykernel_launcher load step completed in 1.74 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748247561.2652345 is LOADED and contains no failed jobs
# Loading page 103 from mvc_persons with offset 5100000
# Pipeline dlt_ipykernel_launcher load step completed in 0.56 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748247662.4952774 is LOADED and contains no failed jobs
# Loading page 104 from mvc_persons with offset 5150000
# Pipeline dlt_ipykernel_launcher load step completed in 1.90 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748247761.0646298 is LOADED and contains no failed jobs
# Loading page 105 from mvc_persons with offset 5200000
# Pipeline dlt_ipykernel_launcher load step completed in 1.77 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748247860.598752 is LOADED and contains no failed jobs
# Loading page 106 from mvc_persons with offset 5250000
# Pipeline dlt_ipykernel_launcher load step completed in 1.92 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748247961.4484353 is LOADED and contains no failed jobs
# Loading page 107 from mvc_persons with offset 5300000
# Pipeline dlt_ipykernel_launcher load step completed in 8.77 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748248063.6283398 is LOADED and contains no failed jobs
# Loading page 108 from mvc_persons with offset 5350000
# Pipeline dlt_ipykernel_launcher load step completed in 2.27 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748248170.505861 is LOADED and contains no failed jobs
# Loading page 109 from mvc_persons with offset 5400000
# Pipeline dlt_ipykernel_launcher load step completed in 1.25 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748248274.1679583 is LOADED and contains no failed jobs
# Loading page 110 from mvc_persons with offset 5450000
# Pipeline dlt_ipykernel_launcher load step completed in 2.64 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748248378.3872597 is LOADED and contains no failed jobs
# Loading page 111 from mvc_persons with offset 5500000
# Pipeline dlt_ipykernel_launcher load step completed in 1.80 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748248481.7106836 is LOADED and contains no failed jobs
# Loading page 112 from mvc_persons with offset 5550000
# Pipeline dlt_ipykernel_launcher load step completed in 1.74 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748248584.5103762 is LOADED and contains no failed jobs
# Loading page 113 from mvc_persons with offset 5600000
# Pipeline dlt_ipykernel_launcher load step completed in 1.69 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748248687.174073 is LOADED and contains no failed jobs
# Loading page 114 from mvc_persons with offset 5650000
# Pipeline dlt_ipykernel_launcher load step completed in 0.93 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748248792.3810115 is LOADED and contains no failed jobs

# %%
try:    
    for source in src_dict.keys():
        page_max_offset = 50000
        page_offset = 0
        page = 1
        name = src_dict[source]
        response = requests.get(f"{source}?$limit=1000&$offset={page_max_offset}")
        while len(response.json()) != 0:
            data_list = []
            for page_data in load_from_source(source, page_offset, page_max_offset):
                # Convert the page to a DataFrame
                data_list.extend(page_data)
            df = pd.DataFrame(data_list)
            df.to_csv(f"./raw/{name}/{name}_{page}.csv", index=False)
            page_offset += 50000
            page += 1
            response = requests.get(f"{source}?$limit=1000&$offset={(page_offset+1000)}")
            page_max_offset +=50000
except:
    print("Error occurred while fetching data from the API.")
# The data is saved in the raw folder with the following structure:
# raw/
# mvc_crashes/mvc_crashes_1.csv
# mvc_vehicles/mvc_vehicles_1.csv
# mvc_persons/mvc_persons_1.csv
# The csv file saves 50000 rows per page
        
#crashes - 44 pages, vehicles - 87 pages, persons - 113 pages

# %%
def rearrange_collision_id(data):
    cols = list(data.columns)
    column_list = ['collision_id']
    column_list.extend(cols[:cols.index('collision_id')])
    column_list.extend(cols[cols.index('collision_id')+1:])
    data = data.reindex(columns=column_list)
    return data

# %%
def reduce_nulls(data):
    threshold = 0.3
    null_percentage = data.isnull().sum() / len(data)
    cols_to_drop = null_percentage[null_percentage > threshold].index
    data = data.drop(columns=cols_to_drop)
    return data

# %%
def convert_dataframe(data):  
    for column in data.columns:
        if column == "crash_date":
            data[column] = pd.to_datetime(data[column])
        if column == "crash_time":
            data[column] = pd.to_datetime(data[column], format='%H:%M').dt.time
        if data[column].dtype == "object":
            data[column] = data[column].fillna("N/A")
            data[column] = data[column].astype(str)
            
        if data[column].dtype == "int64" or data[column].dtype == "float64":
            data[column] = data[column].fillna(0)
    return data

# %%
def remove_unavailable(data):
    cols_to_drop = []
    for column in data.columns:
        if data[column].dtype == "object":
            if len(data[column]=="N/A")/len(data[column]) > 0.7:
                cols_to_drop.append(column)
        elif data[column].dtype == "int64" or data[column].dtype == "float64":
            if len(data[column]==0)/len(data[column]) > 0.7:
                cols_to_drop.append(column)
    data = data.drop(columns=cols_to_drop)
    return data

# %%
def transform_df_crashes(data):
    
    data["crash_date"] = pd.to_datetime(data["crash_date"])
    data["crash_time"] = pd.to_datetime(data["crash_time"], format='%H:%M').dt.time
    
    data['contributing_factor_vehicle_1'] = data['contributing_factor_vehicle_1'].fillna('N/A')
    data['contributing_factor_vehicle_1'] = data['contributing_factor_vehicle_1'].astype(str)
    
    data['vehicle_type_code1'] = data['vehicle_type_code1'].fillna('N/A')
    data['vehicle_type_code1'] = data['vehicle_type_code1'].astype(str)
    
    data['latitude'] = data['latitude'].fillna(0)
    data['longitude'] = data['longitude'].fillna(0)
    
    data.drop('location', axis=1, inplace=True)
    return data

# %%
def transform_df_vehicles(data):
    
    data["crash_date"] = pd.to_datetime(data["crash_date"])
    data["crash_time"] = pd.to_datetime(data["crash_time"], format='%H:%M').dt.time
    data["vehicle_id"] = data["vehicle_id"].astype(str)

    data['state_registration'] = data['state_registration'].fillna('N/A')
    data["state_registration"] = data["state_registration"].astype(str)

    data['vehicle_type'] = data['vehicle_type'].fillna('N/A')
    data['vehicle_type'] = data['vehicle_type'].astype(str)

    data['contributing_factor_1'] = data['contributing_factor_1'].fillna('N/A')
    data['contributing_factor_1'] = data['contributing_factor_1'].astype(str)
    

    return data

# %%
def transform_df_persons(data):
    
    data["crash_date"] = pd.to_datetime(data["crash_date"])
    data["crash_time"] = pd.to_datetime(data["crash_time"], format='%H:%M').dt.time

    data["person_id"] = data["person_id"].fillna('N/A')
    data["person_id"] = data["person_id"].astype(str)

    data["person_type"] = data["person_type"].astype(str)
    data["person_injury"] = data["person_injury"].astype(str)

    data['ped_role'] = data['ped_role'].fillna('N/A')
    data["ped_role"] = data["ped_role"].astype(str)
    
    
    return data

# %%
def transform_and_load(data):
    
    # For example, you can rename columns, change data types, etc.
    data = rearrange_collision_id(data)
    
    # if name == "mvc_crashes":
    #     data = transform_df_crashes(data)
    # elif name == "mvc_vehicles":
    #     data = transform_df_vehicles(data)
    # elif name == "mvc_persons":
    #     data = transform_df_persons(data)
    data = reduce_nulls(data)
    data = convert_dataframe(data)
    
    return data

# %%
df = pd.read_csv("./data/raw/mvc_persons/mvc_persons_1.csv")
df = transform_and_load(df)
list(df.columns)
# Out:
# ['collision_id',
#  'unique_id',
#  'crash_date',
#  'crash_time',
#  'person_id',
#  'person_type',
#  'person_injury',
#  'ped_role']

# %%
path = Path("./data/raw")
for roots,dirs,files in path.walk(on_error=print):
    for dir in dirs:
        path = Path(roots) / dir
        name = dir
        page = 1
        required_columns = []
        if name == "mvc_crashes":
            required_columns = ['collision_id',
                                'crash_date',
                                'crash_time',
                                'on_street_name',
                                'number_of_persons_injured',
                                'number_of_persons_killed',
                                'number_of_pedestrians_injured',
                                'number_of_pedestrians_killed',
                                'number_of_cyclist_injured',
                                'number_of_cyclist_killed',
                                'number_of_motorist_injured',
                                'number_of_motorist_killed',
                                'contributing_factor_vehicle_1',
                                'contributing_factor_vehicle_2',
                                'vehicle_type_code1',
                                'latitude',
                                'longitude',
                                'location']
        elif name == "mvc_vehicles":
            required_columns = ['collision_id',
                                'unique_id',
                                'crash_date',
                                'crash_time',
                                'vehicle_id',
                                'state_registration',
                                'vehicle_type',
                                'contributing_factor_1']
        elif name == "mvc_persons":
            required_columns = ['collision_id',
                                'unique_id',
                                'crash_date',
                                'crash_time',
                                'person_id',
                                'person_type',
                                'person_injury',
                                'ped_role']
        try:
            for file in path.glob("*.csv"):
                print(f"Transforming and loading data for {file.name.split('.')[0]}")
                df = pd.read_csv(file)
                df = transform_and_load(df)
                if list(df.columns) != required_columns:
                    df = df[required_columns]
                df.to_csv(f"./data/transformed/{name}/{file.name}", index=False)
                page += 1
        except Exception as e:
            print(f"Error occurred while transforming and loading data: {e}")
            continue
# Out:
# Transforming and loading data for mvc_crashes_1
# Transforming and loading data for mvc_crashes_10
# Transforming and loading data for mvc_crashes_11
# Transforming and loading data for mvc_crashes_12
# Transforming and loading data for mvc_crashes_13
# Transforming and loading data for mvc_crashes_14
# Transforming and loading data for mvc_crashes_15
# Transforming and loading data for mvc_crashes_16
# Transforming and loading data for mvc_crashes_17
# Transforming and loading data for mvc_crashes_18
# Transforming and loading data for mvc_crashes_19
# Transforming and loading data for mvc_crashes_2
# Transforming and loading data for mvc_crashes_20
# Transforming and loading data for mvc_crashes_21
# Transforming and loading data for mvc_crashes_22
# Transforming and loading data for mvc_crashes_23
# Transforming and loading data for mvc_crashes_24
# Transforming and loading data for mvc_crashes_25
# Transforming and loading data for mvc_crashes_26
# Transforming and loading data for mvc_crashes_27
# Error occurred while transforming and loading data: "['latitude', 'longitude', 'location'] not in index"
# Transforming and loading data for mvc_persons_1
# Transforming and loading data for mvc_persons_10
# Transforming and loading data for mvc_persons_100
# Transforming and loading data for mvc_persons_101
# Transforming and loading data for mvc_persons_102
# Transforming and loading data for mvc_persons_103
# Transforming and loading data for mvc_persons_104
# Transforming and loading data for mvc_persons_105
# Transforming and loading data for mvc_persons_106
# Transforming and loading data for mvc_persons_107
# Transforming and loading data for mvc_persons_108
# Transforming and loading data for mvc_persons_109
# Transforming and loading data for mvc_persons_11
# Transforming and loading data for mvc_persons_110
# Transforming and loading data for mvc_persons_111
# Transforming and loading data for mvc_persons_112
# Transforming and loading data for mvc_persons_113
# Transforming and loading data for mvc_persons_114
# Transforming and loading data for mvc_persons_12
# Transforming and loading data for mvc_persons_13
# Transforming and loading data for mvc_persons_14
# Transforming and loading data for mvc_persons_15
# Transforming and loading data for mvc_persons_16
# Transforming and loading data for mvc_persons_17
# Transforming and loading data for mvc_persons_18
# Transforming and loading data for mvc_persons_19
# Transforming and loading data for mvc_persons_2
# Transforming and loading data for mvc_persons_20
# Transforming and loading data for mvc_persons_21
# Transforming and loading data for mvc_persons_22
# Transforming and loading data for mvc_persons_23
# Transforming and loading data for mvc_persons_24
# Transforming and loading data for mvc_persons_25
# Transforming and loading data for mvc_persons_26
# Transforming and loading data for mvc_persons_27
# Transforming and loading data for mvc_persons_28
# Transforming and loading data for mvc_persons_29
# Transforming and loading data for mvc_persons_3
# Transforming and loading data for mvc_persons_30
# Transforming and loading data for mvc_persons_31
# Transforming and loading data for mvc_persons_32
# Transforming and loading data for mvc_persons_33
# Transforming and loading data for mvc_persons_34
# Transforming and loading data for mvc_persons_35
# Transforming and loading data for mvc_persons_36
# Transforming and loading data for mvc_persons_37
# Transforming and loading data for mvc_persons_38
# Transforming and loading data for mvc_persons_39
# Transforming and loading data for mvc_persons_4
# Transforming and loading data for mvc_persons_40
# Transforming and loading data for mvc_persons_41
# Transforming and loading data for mvc_persons_42
# Transforming and loading data for mvc_persons_43
# Transforming and loading data for mvc_persons_44
# Transforming and loading data for mvc_persons_45
# Transforming and loading data for mvc_persons_46
# Transforming and loading data for mvc_persons_47
# Transforming and loading data for mvc_persons_48
# Transforming and loading data for mvc_persons_49
# Transforming and loading data for mvc_persons_5
# Transforming and loading data for mvc_persons_50
# Transforming and loading data for mvc_persons_51
# Transforming and loading data for mvc_persons_52
# Transforming and loading data for mvc_persons_53
# Transforming and loading data for mvc_persons_54
# Transforming and loading data for mvc_persons_55
# Transforming and loading data for mvc_persons_56
# Transforming and loading data for mvc_persons_57
# Transforming and loading data for mvc_persons_58
# Transforming and loading data for mvc_persons_59
# Transforming and loading data for mvc_persons_6
# Transforming and loading data for mvc_persons_60
# Transforming and loading data for mvc_persons_61
# Transforming and loading data for mvc_persons_62
# Transforming and loading data for mvc_persons_63
# Transforming and loading data for mvc_persons_64
# Transforming and loading data for mvc_persons_65
# Transforming and loading data for mvc_persons_66
# Transforming and loading data for mvc_persons_67
# Transforming and loading data for mvc_persons_68
# Transforming and loading data for mvc_persons_69
# Transforming and loading data for mvc_persons_7
# Transforming and loading data for mvc_persons_70
# Transforming and loading data for mvc_persons_71
# Transforming and loading data for mvc_persons_72
# Transforming and loading data for mvc_persons_73
# Transforming and loading data for mvc_persons_74
# Transforming and loading data for mvc_persons_75
# Transforming and loading data for mvc_persons_76
# Transforming and loading data for mvc_persons_77
# Transforming and loading data for mvc_persons_78
# Transforming and loading data for mvc_persons_79
# Transforming and loading data for mvc_persons_8
# Transforming and loading data for mvc_persons_80
# Transforming and loading data for mvc_persons_81
# Transforming and loading data for mvc_persons_82
# Transforming and loading data for mvc_persons_83
# Transforming and loading data for mvc_persons_84
# Transforming and loading data for mvc_persons_85
# Transforming and loading data for mvc_persons_86
# Transforming and loading data for mvc_persons_87
# Transforming and loading data for mvc_persons_88
# Transforming and loading data for mvc_persons_89
# Transforming and loading data for mvc_persons_9
# Transforming and loading data for mvc_persons_90
# Transforming and loading data for mvc_persons_91
# Transforming and loading data for mvc_persons_92
# Transforming and loading data for mvc_persons_93
# Transforming and loading data for mvc_persons_94
# Transforming and loading data for mvc_persons_95
# Transforming and loading data for mvc_persons_96
# Transforming and loading data for mvc_persons_97
# Transforming and loading data for mvc_persons_98
# Transforming and loading data for mvc_persons_99
# Transforming and loading data for mvc_vehicles_1
# Transforming and loading data for mvc_vehicles_10
# Transforming and loading data for mvc_vehicles_11
# Transforming and loading data for mvc_vehicles_12
# Transforming and loading data for mvc_vehicles_13
# Transforming and loading data for mvc_vehicles_14
# Transforming and loading data for mvc_vehicles_15
# Transforming and loading data for mvc_vehicles_16
# Transforming and loading data for mvc_vehicles_17
# Transforming and loading data for mvc_vehicles_18
# Transforming and loading data for mvc_vehicles_19
# Transforming and loading data for mvc_vehicles_2
# Transforming and loading data for mvc_vehicles_20
# Transforming and loading data for mvc_vehicles_21
# Transforming and loading data for mvc_vehicles_22
# Transforming and loading data for mvc_vehicles_23
# Transforming and loading data for mvc_vehicles_24
# Transforming and loading data for mvc_vehicles_25
# Transforming and loading data for mvc_vehicles_26
# Transforming and loading data for mvc_vehicles_27
# Transforming and loading data for mvc_vehicles_28
# Transforming and loading data for mvc_vehicles_29
# Transforming and loading data for mvc_vehicles_3
# Transforming and loading data for mvc_vehicles_30
# Transforming and loading data for mvc_vehicles_31
# Transforming and loading data for mvc_vehicles_32
# Transforming and loading data for mvc_vehicles_33
# Transforming and loading data for mvc_vehicles_34
# Transforming and loading data for mvc_vehicles_35
# Transforming and loading data for mvc_vehicles_36
# Transforming and loading data for mvc_vehicles_37
# Transforming and loading data for mvc_vehicles_38
# Transforming and loading data for mvc_vehicles_39
# Transforming and loading data for mvc_vehicles_4
# Transforming and loading data for mvc_vehicles_40
# /tmp/ipykernel_31108/2139989616.py:48: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# Transforming and loading data for mvc_vehicles_41
# Transforming and loading data for mvc_vehicles_42
# Transforming and loading data for mvc_vehicles_43
# Transforming and loading data for mvc_vehicles_44
# Transforming and loading data for mvc_vehicles_45
# Transforming and loading data for mvc_vehicles_46
# Transforming and loading data for mvc_vehicles_47
# Transforming and loading data for mvc_vehicles_48
# Transforming and loading data for mvc_vehicles_49
# /tmp/ipykernel_31108/2139989616.py:48: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# Transforming and loading data for mvc_vehicles_5
# Transforming and loading data for mvc_vehicles_50
# Transforming and loading data for mvc_vehicles_51
# Transforming and loading data for mvc_vehicles_52
# Transforming and loading data for mvc_vehicles_53
# Transforming and loading data for mvc_vehicles_54
# Transforming and loading data for mvc_vehicles_55
# Transforming and loading data for mvc_vehicles_56
# /tmp/ipykernel_31108/2139989616.py:48: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# Transforming and loading data for mvc_vehicles_57
# Transforming and loading data for mvc_vehicles_58
# Transforming and loading data for mvc_vehicles_59
# /tmp/ipykernel_31108/2139989616.py:48: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# Transforming and loading data for mvc_vehicles_6
# Transforming and loading data for mvc_vehicles_60
# /tmp/ipykernel_31108/2139989616.py:48: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# Transforming and loading data for mvc_vehicles_61
# Transforming and loading data for mvc_vehicles_62
# Transforming and loading data for mvc_vehicles_63
# Transforming and loading data for mvc_vehicles_64
# /tmp/ipykernel_31108/2139989616.py:48: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# Transforming and loading data for mvc_vehicles_65
# Transforming and loading data for mvc_vehicles_66
# Transforming and loading data for mvc_vehicles_67
# Transforming and loading data for mvc_vehicles_68
# Transforming and loading data for mvc_vehicles_69
# Transforming and loading data for mvc_vehicles_7
# Transforming and loading data for mvc_vehicles_70
# /tmp/ipykernel_31108/2139989616.py:48: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# Transforming and loading data for mvc_vehicles_71
# Transforming and loading data for mvc_vehicles_72
# /tmp/ipykernel_31108/2139989616.py:48: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# Transforming and loading data for mvc_vehicles_73
# Transforming and loading data for mvc_vehicles_74
# Transforming and loading data for mvc_vehicles_75
# /tmp/ipykernel_31108/2139989616.py:48: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# Transforming and loading data for mvc_vehicles_76
# Transforming and loading data for mvc_vehicles_77
# Transforming and loading data for mvc_vehicles_78
# Transforming and loading data for mvc_vehicles_79
# Transforming and loading data for mvc_vehicles_8
# Transforming and loading data for mvc_vehicles_80
# Transforming and loading data for mvc_vehicles_81
# Transforming and loading data for mvc_vehicles_82
# Transforming and loading data for mvc_vehicles_83
# Transforming and loading data for mvc_vehicles_84
# /tmp/ipykernel_31108/2139989616.py:48: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# Transforming and loading data for mvc_vehicles_85
# Transforming and loading data for mvc_vehicles_86
# Transforming and loading data for mvc_vehicles_87
# /tmp/ipykernel_31108/2139989616.py:48: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# Transforming and loading data for mvc_vehicles_88
# Transforming and loading data for mvc_vehicles_9

# %%
try:    
    path = Path("./raw")
    for roots,dirs,files in path.walk(on_error=print):
        for dir in dirs:
            path = Path(roots) / dir
            name = dir
            for file in path.glob("*.csv"):
                df = pd.read_csv(file)
                transform_and_load(df,name)
except:
    print("Error occurred while transforming and loading data.")

# %%
df_crashes_27 = pd.read_csv("./data/raw/mvc_crashes/mvc_crashes_27.csv")
df_crashes_27 = rearrange_collision_id(df_crashes_27)
df_crashes_27 = reduce_nulls(df_crashes_27)
df_crashes_27.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   collision_id                   50000 non-null  int64
#  1   crash_date                     50000 non-null  object
#  2   crash_time                     50000 non-null  object
#  3   number_of_persons_injured      49998 non-null  float64
#  4   number_of_persons_killed       49998 non-null  float64
#  5   number_of_pedestrians_injured  50000 non-null  int64
#  6   number_of_pedestrians_killed   50000 non-null  int64
#  7   number_of_cyclist_injured      50000 non-null  int64
#  8   number_of_cyclist_killed       50000 non-null  int64
#  9   number_of_motorist_injured     50000 non-null  int64
#  10  number_of_motorist_killed      50000 non-null  int64
#  11  contributing_factor_vehicle_1  49778 non-null  object
#  12  contributing_factor_vehicle_2  42775 non-null  object
#  13  vehicle_type_code1             49189 non-null  object
#  14  vehicle_type_code2             40883 non-null  object
#  15  borough                        35295 non-null  object
#  16  zip_code                       35283 non-null  float64
#  17  on_street_name                 36351 non-null  object
# dtypes: float64(3), int64(7), object(8)
# memory usage: 6.9+ MB

# %%
def df_info_to_json(df):
    buffer = io.StringIO()
    df.info(buf=buffer)
    info_str = buffer.getvalue()

    lines = info_str.strip().split('\n')
    data = {}

    data["columns"] = []
    for line in lines[5:-2]:
        parts = line.split()
        data["columns"].append({
            "index": parts[0],
            "column": parts[1],
            "non-null count": parts[2],
            "dtype": parts[4]
        })
    
    return json.dumps(data)

# %%
metadata_df = pd.DataFrame(columns=["filename", "number_of_columns", "file_info"])
insert_df = pd.DataFrame([['mvc_vehicles_1',9,df_info_to_json(df_transformed_vehicles)]], columns=["filename", "number_of_columns", "file_info"])
metadata_df = pd.concat([metadata_df, insert_df], ignore_index=True)
len(metadata_df.columns)
# Out:
# 3

# %%
metadata_df = pd.DataFrame(columns=["filename", "number_of_columns", "file_info"])
path = Path("./data/transformed")
for roots,dirs,files in path.walk(on_error=print):
    for dir in dirs:
        path = Path(roots) / dir
        name = dir
        page = 1
        for file in path.glob("*.csv"):
            print(f"Checking data for {name}, page {page}")
            df = pd.read_csv(file)
            file_info = df_info_to_json(df)
            insert_df = pd.DataFrame([[file.name,len(df.columns),file_info]], columns=["filename", "number_of_columns", "file_info"])
            metadata_df = pd.concat([metadata_df, insert_df], ignore_index=True)
            page += 1
metadata_df.to_csv("./data/transformed_metadata.csv", index=False)
# Out:
# Checking data for mvc_crashes, page 1
# Checking data for mvc_crashes, page 2
# Checking data for mvc_crashes, page 3
# Checking data for mvc_crashes, page 4
# Checking data for mvc_crashes, page 5
# Checking data for mvc_crashes, page 6
# Checking data for mvc_crashes, page 7
# Checking data for mvc_crashes, page 8
# Checking data for mvc_crashes, page 9
# Checking data for mvc_crashes, page 10
# Checking data for mvc_crashes, page 11
# Checking data for mvc_crashes, page 12
# Checking data for mvc_crashes, page 13
# Checking data for mvc_crashes, page 14
# Checking data for mvc_crashes, page 15
# Checking data for mvc_crashes, page 16
# Checking data for mvc_crashes, page 17
# Checking data for mvc_crashes, page 18
# Checking data for mvc_crashes, page 19
# Checking data for mvc_persons, page 1
# Checking data for mvc_persons, page 2
# Checking data for mvc_persons, page 3
# Checking data for mvc_persons, page 4
# Checking data for mvc_persons, page 5
# Checking data for mvc_persons, page 6
# Checking data for mvc_persons, page 7
# Checking data for mvc_persons, page 8
# Checking data for mvc_persons, page 9
# Checking data for mvc_persons, page 10
# Checking data for mvc_persons, page 11
# Checking data for mvc_persons, page 12
# Checking data for mvc_persons, page 13
# Checking data for mvc_persons, page 14
# Checking data for mvc_persons, page 15
# Checking data for mvc_persons, page 16
# Checking data for mvc_persons, page 17
# Checking data for mvc_persons, page 18
# Checking data for mvc_persons, page 19
# Checking data for mvc_persons, page 20
# Checking data for mvc_persons, page 21
# Checking data for mvc_persons, page 22
# Checking data for mvc_persons, page 23
# Checking data for mvc_persons, page 24
# Checking data for mvc_persons, page 25
# Checking data for mvc_persons, page 26
# Checking data for mvc_persons, page 27
# Checking data for mvc_persons, page 28
# Checking data for mvc_persons, page 29
# Checking data for mvc_persons, page 30
# Checking data for mvc_persons, page 31
# Checking data for mvc_persons, page 32
# Checking data for mvc_persons, page 33
# Checking data for mvc_persons, page 34
# Checking data for mvc_persons, page 35
# Checking data for mvc_persons, page 36
# Checking data for mvc_persons, page 37
# Checking data for mvc_persons, page 38
# Checking data for mvc_persons, page 39
# Checking data for mvc_persons, page 40
# Checking data for mvc_persons, page 41
# Checking data for mvc_persons, page 42
# Checking data for mvc_persons, page 43
# Checking data for mvc_persons, page 44
# Checking data for mvc_persons, page 45
# Checking data for mvc_persons, page 46
# Checking data for mvc_persons, page 47
# Checking data for mvc_persons, page 48
# Checking data for mvc_persons, page 49
# Checking data for mvc_persons, page 50
# Checking data for mvc_persons, page 51
# Checking data for mvc_persons, page 52
# Checking data for mvc_persons, page 53
# Checking data for mvc_persons, page 54
# Checking data for mvc_persons, page 55
# Checking data for mvc_persons, page 56
# Checking data for mvc_persons, page 57
# Checking data for mvc_persons, page 58
# Checking data for mvc_persons, page 59
# Checking data for mvc_persons, page 60
# Checking data for mvc_persons, page 61
# Checking data for mvc_persons, page 62
# Checking data for mvc_persons, page 63
# Checking data for mvc_persons, page 64
# Checking data for mvc_persons, page 65
# Checking data for mvc_persons, page 66
# Checking data for mvc_persons, page 67
# Checking data for mvc_persons, page 68
# Checking data for mvc_persons, page 69
# Checking data for mvc_persons, page 70
# Checking data for mvc_persons, page 71
# Checking data for mvc_persons, page 72
# Checking data for mvc_persons, page 73
# Checking data for mvc_persons, page 74
# Checking data for mvc_persons, page 75
# Checking data for mvc_persons, page 76
# Checking data for mvc_persons, page 77
# Checking data for mvc_persons, page 78
# Checking data for mvc_persons, page 79
# Checking data for mvc_persons, page 80
# Checking data for mvc_persons, page 81
# Checking data for mvc_persons, page 82
# Checking data for mvc_persons, page 83
# Checking data for mvc_persons, page 84
# Checking data for mvc_persons, page 85
# Checking data for mvc_persons, page 86
# Checking data for mvc_persons, page 87
# Checking data for mvc_persons, page 88
# Checking data for mvc_persons, page 89
# Checking data for mvc_persons, page 90
# Checking data for mvc_persons, page 91
# Checking data for mvc_persons, page 92
# Checking data for mvc_persons, page 93
# Checking data for mvc_persons, page 94
# Checking data for mvc_persons, page 95
# Checking data for mvc_persons, page 96
# Checking data for mvc_persons, page 97
# Checking data for mvc_persons, page 98
# Checking data for mvc_persons, page 99
# Checking data for mvc_persons, page 100
# Checking data for mvc_persons, page 101
# Checking data for mvc_persons, page 102
# Checking data for mvc_persons, page 103
# Checking data for mvc_persons, page 104
# Checking data for mvc_persons, page 105
# Checking data for mvc_persons, page 106
# Checking data for mvc_persons, page 107
# Checking data for mvc_persons, page 108
# Checking data for mvc_persons, page 109
# Checking data for mvc_persons, page 110
# Checking data for mvc_persons, page 111
# Checking data for mvc_persons, page 112
# Checking data for mvc_persons, page 113
# Checking data for mvc_persons, page 114
# Checking data for mvc_vehicles, page 1
# Checking data for mvc_vehicles, page 2
# Checking data for mvc_vehicles, page 3
# Checking data for mvc_vehicles, page 4
# Checking data for mvc_vehicles, page 5
# Checking data for mvc_vehicles, page 6
# Checking data for mvc_vehicles, page 7
# Checking data for mvc_vehicles, page 8
# Checking data for mvc_vehicles, page 9
# Checking data for mvc_vehicles, page 10
# Checking data for mvc_vehicles, page 11
# Checking data for mvc_vehicles, page 12
# Checking data for mvc_vehicles, page 13
# Checking data for mvc_vehicles, page 14
# Checking data for mvc_vehicles, page 15
# Checking data for mvc_vehicles, page 16
# Checking data for mvc_vehicles, page 17
# Checking data for mvc_vehicles, page 18
# Checking data for mvc_vehicles, page 19
# Checking data for mvc_vehicles, page 20
# Checking data for mvc_vehicles, page 21
# Checking data for mvc_vehicles, page 22
# Checking data for mvc_vehicles, page 23
# Checking data for mvc_vehicles, page 24
# Checking data for mvc_vehicles, page 25
# Checking data for mvc_vehicles, page 26
# Checking data for mvc_vehicles, page 27
# Checking data for mvc_vehicles, page 28
# Checking data for mvc_vehicles, page 29
# Checking data for mvc_vehicles, page 30
# Checking data for mvc_vehicles, page 31
# Checking data for mvc_vehicles, page 32
# Checking data for mvc_vehicles, page 33
# Checking data for mvc_vehicles, page 34
# Checking data for mvc_vehicles, page 35
# Checking data for mvc_vehicles, page 36
# Checking data for mvc_vehicles, page 37
# Checking data for mvc_vehicles, page 38
# Checking data for mvc_vehicles, page 39
# Checking data for mvc_vehicles, page 40
# Checking data for mvc_vehicles, page 41
# Checking data for mvc_vehicles, page 42
# Checking data for mvc_vehicles, page 43
# Checking data for mvc_vehicles, page 44
# Checking data for mvc_vehicles, page 45
# Checking data for mvc_vehicles, page 46
# Checking data for mvc_vehicles, page 47
# Checking data for mvc_vehicles, page 48
# Checking data for mvc_vehicles, page 49
# Checking data for mvc_vehicles, page 50
# Checking data for mvc_vehicles, page 51
# Checking data for mvc_vehicles, page 52
# Checking data for mvc_vehicles, page 53
# Checking data for mvc_vehicles, page 54
# Checking data for mvc_vehicles, page 55
# Checking data for mvc_vehicles, page 56
# Checking data for mvc_vehicles, page 57
# Checking data for mvc_vehicles, page 58
# Checking data for mvc_vehicles, page 59
# Checking data for mvc_vehicles, page 60
# Checking data for mvc_vehicles, page 61
# Checking data for mvc_vehicles, page 62
# Checking data for mvc_vehicles, page 63
# Checking data for mvc_vehicles, page 64
# Checking data for mvc_vehicles, page 65
# Checking data for mvc_vehicles, page 66
# Checking data for mvc_vehicles, page 67
# Checking data for mvc_vehicles, page 68
# Checking data for mvc_vehicles, page 69
# Checking data for mvc_vehicles, page 70
# Checking data for mvc_vehicles, page 71
# Checking data for mvc_vehicles, page 72
# Checking data for mvc_vehicles, page 73
# Checking data for mvc_vehicles, page 74
# Checking data for mvc_vehicles, page 75
# Checking data for mvc_vehicles, page 76
# Checking data for mvc_vehicles, page 77
# Checking data for mvc_vehicles, page 78
# Checking data for mvc_vehicles, page 79
# Checking data for mvc_vehicles, page 80
# Checking data for mvc_vehicles, page 81
# Checking data for mvc_vehicles, page 82
# Checking data for mvc_vehicles, page 83
# Checking data for mvc_vehicles, page 84
# Checking data for mvc_vehicles, page 85
# Checking data for mvc_vehicles, page 86
# Checking data for mvc_vehicles, page 87
# Checking data for mvc_vehicles, page 88

# %%
path = Path("./data/transformed")
for roots,dirs,files in path.walk(on_error=print):
    for dir in dirs:
        path = Path(roots) / dir
        name = dir
        page = 1
        for file in path.glob("*.csv"):
            print(file.name)
            break

# %%
df = pd.read_csv("./data/transfomed_metadata.csv")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 df = pd.read_csv("./data/transfomed_metadata.csv")
#       2 df
#
# File /mnt/d/Projects/motor-vehicle-collisions/.venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /mnt/d/Projects/motor-vehicle-collisions/.venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /mnt/d/Projects/motor-vehicle-collisions/.venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /mnt/d/Projects/motor-vehicle-collisions/.venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /mnt/d/Projects/motor-vehicle-collisions/.venv/lib/python3.13/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/transfomed_metadata.csv'
