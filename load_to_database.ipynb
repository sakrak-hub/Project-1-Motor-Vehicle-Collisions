# %%
import pandas as pd
import psycopg2
import dlt
from dlt.sources.helpers.rest_client import RESTClient
from pathlib import Path

# %%
def add_to_pipeline(data,name):

    # Initialize the pipeline
    pipeline = dlt.pipeline(destination="postgres", dataset_name="raw_motor_vehicle_collisions")

    # Run the pipeline
    load_info = pipeline.run(data,table_name=name, write_disposition="append", loader_file_format="csv")

    # Print the load info
    print(load_info)
    # Print the number of rows loaded

# %%
path = Path('./data/transformed')
for roots,dirs,file in path.walk(on_error=print):
    for dir in dirs:
        path = Path(roots) / dir
        name = f"transfomed_{dir}"
        for file in path.glob("*.csv"):
            df = pd.read_csv(file)
            add_to_pipeline(df,name)
# Out:
# Pipeline dlt_ipykernel_launcher load step completed in 0.48 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748229624.0943716 is LOADED and contains no failed jobs
# Pipeline dlt_ipykernel_launcher load step completed in 0.26 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748229626.0066736 is LOADED and contains no failed jobs
# Pipeline dlt_ipykernel_launcher load step completed in 0.25 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748229627.7143981 is LOADED and contains no failed jobs
# Pipeline dlt_ipykernel_launcher load step completed in 0.27 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748229629.2844894 is LOADED and contains no failed jobs
# Pipeline dlt_ipykernel_launcher load step completed in 0.27 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748229630.837843 is LOADED and contains no failed jobs
# Pipeline dlt_ipykernel_launcher load step completed in 0.28 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748229632.4789443 is LOADED and contains no failed jobs
# Pipeline dlt_ipykernel_launcher load step completed in 0.30 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748229634.121459 is LOADED and contains no failed jobs
# Pipeline dlt_ipykernel_launcher load step completed in 0.24 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748229635.7181072 is LOADED and contains no failed jobs
# Pipeline dlt_ipykernel_launcher load step completed in 0.29 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748229637.2978146 is LOADED and contains no failed jobs
# Pipeline dlt_ipykernel_launcher load step completed in 0.33 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748229638.91567 is LOADED and contains no failed jobs
# Pipeline dlt_ipykernel_launcher load step completed in 0.32 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748229640.5442724 is LOADED and contains no failed jobs
# Pipeline dlt_ipykernel_launcher load step completed in 0.39 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748229642.180126 is LOADED and contains no failed jobs
# Pipeline dlt_ipykernel_launcher load step completed in 0.29 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748229643.8763256 is LOADED and contains no failed jobs
# Pipeline dlt_ipykernel_launcher load step completed in 0.30 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748229645.4758832 is LOADED and contains no failed jobs
# Pipeline dlt_ipykernel_launcher load step completed in 0.39 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748229647.0981 is LOADED and contains no failed jobs
# Pipeline dlt_ipykernel_launcher load step completed in 0.37 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748229648.916681 is LOADED and contains no failed jobs
# Pipeline dlt_ipykernel_launcher load step completed in 59 minutes and 58.85 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748229650.7016752 is LOADED and contains no failed jobs
# Pipeline dlt_ipykernel_launcher load step completed in 0.31 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748229650.9278097 is LOADED and contains no failed jobs
# Pipeline dlt_ipykernel_launcher load step completed in 0.34 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748229652.6049724 is LOADED and contains no failed jobs
# Pipeline dlt_ipykernel_launcher load step completed in 0.38 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748229654.2525337 is LOADED and contains no failed jobs
# Pipeline dlt_ipykernel_launcher load step completed in 0.40 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748229655.8909476 is LOADED and contains no failed jobs
# Pipeline dlt_ipykernel_launcher load step completed in 0.36 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748229657.9368994 is LOADED and contains no failed jobs
# Pipeline dlt_ipykernel_launcher load step completed in 0.37 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748229659.9106252 is LOADED and contains no failed jobs
# Pipeline dlt_ipykernel_launcher load step completed in 0.37 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748229661.677316 is LOADED and contains no failed jobs
# Pipeline dlt_ipykernel_launcher load step completed in 0.34 seconds
# 1 load package(s) were loaded to destination postgres and into dataset motor_vehicle_collisions
# The postgres destination used postgresql://loader:***@localhost:5432/dlt_data location to store data
# Load package 1748229663.667024 is LOADED and contains no failed jobs
# 2025-05-26 11:21:07,122|[ERROR]|995|140615677372096|dlt|load.py|w_run_job:247|Transient exception in job transfomed_mvc_crashes.285db8faa3.csv in file /home/ksakra/.dlt/pipelines/dlt_ipykernel_launcher/load/normalized/1748229665.6249466/started_jobs/transfomed_mvc_crashes.285db8faa3.0.csv
# Traceback (most recent call last):
#   File "/mnt/d/Projects/Project-1-Motor-Vehicle-Collisions-/.venv/lib/python3.13/site-packages/dlt/common/destination/client.py", line 404, in run_managed
#     self.run()
#     ~~~~~~~~^^
#   File "/mnt/d/Projects/Project-1-Motor-Vehicle-Collisions-/.venv/lib/python3.13/site-packages/dlt/destinations/impl/postgres/postgres.py", line 133, in run
#     cursor.copy_expert(copy_sql, f, size=8192)
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
# psycopg2.errors.InvalidTextRepresentation: invalid input syntax for type double precision: "     "
# CONTEXT:  COPY transfomed_mvc_crashes, line 17724, column zip_code: "     "
#
# 2025-05-26 11:21:07,974|[WARNING]|995|140617910724416|dlt|load.py|complete_jobs:430|Job for transfomed_mvc_crashes.285db8faa3.csv retried in load 1748229665.6249466 with message invalid input syntax for type double precision: "     "
# CONTEXT:  COPY transfomed_mvc_crashes, line 17724, column zip_code: "     "
#
# 2025-05-26 11:21:08,119|[ERROR]|995|140615677372096|dlt|load.py|w_run_job:247|Transient exception in job transfomed_mvc_crashes.285db8faa3.csv in file /home/ksakra/.dlt/pipelines/dlt_ipykernel_launcher/load/normalized/1748229665.6249466/started_jobs/transfomed_mvc_crashes.285db8faa3.1.csv
# Traceback (most recent call last):
#   File "/mnt/d/Projects/Project-1-Motor-Vehicle-Collisions-/.venv/lib/python3.13/site-packages/dlt/common/destination/client.py", line 404, in run_managed
#     self.run()
#     ~~~~~~~~^^
#   File "/mnt/d/Projects/Project-1-Motor-Vehicle-Collisions-/.venv/lib/python3.13/site-packages/dlt/destinations/impl/postgres/postgres.py", line 133, in run
#     cursor.copy_expert(copy_sql, f, size=8192)
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
# psycopg2.errors.InvalidTextRepresentation: invalid input syntax for type double precision: "     "
# CONTEXT:  COPY transfomed_mvc_crashes, line 17724, column zip_code: "     "
#
# 2025-05-26 11:21:08,978|[WARNING]|995|140617910724416|dlt|load.py|complete_jobs:430|Job for transfomed_mvc_crashes.285db8faa3.csv retried in load 1748229665.6249466 with message invalid input syntax for type double precision: "     "
# CONTEXT:  COPY transfomed_mvc_crashes, line 17724, column zip_code: "     "
#
# 2025-05-26 11:21:09,135|[ERROR]|995|140615677372096|dlt|load.py|w_run_job:247|Transient exception in job transfomed_mvc_crashes.285db8faa3.csv in file /home/ksakra/.dlt/pipelines/dlt_ipykernel_launcher/load/normalized/1748229665.6249466/started_jobs/transfomed_mvc_crashes.285db8faa3.2.csv
# Traceback (most recent call last):
#   File "/mnt/d/Projects/Project-1-Motor-Vehicle-Collisions-/.venv/lib/python3.13/site-packages/dlt/common/destination/client.py", line 404, in run_managed
#     self.run()
#     ~~~~~~~~^^
#   File "/mnt/d/Projects/Project-1-Motor-Vehicle-Collisions-/.venv/lib/python3.13/site-packages/dlt/destinations/impl/postgres/postgres.py", line 133, in run
#     cursor.copy_expert(copy_sql, f, size=8192)
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
# psycopg2.errors.InvalidTextRepresentation: invalid input syntax for type double precision: "     "
# CONTEXT:  COPY transfomed_mvc_crashes, line 17724, column zip_code: "     "
#
# 2025-05-26 11:21:09,984|[WARNING]|995|140617910724416|dlt|load.py|complete_jobs:430|Job for transfomed_mvc_crashes.285db8faa3.csv retried in load 1748229665.6249466 with message invalid input syntax for type double precision: "     "
# CONTEXT:  COPY transfomed_mvc_crashes, line 17724, column zip_code: "     "
#
# 2025-05-26 11:21:10,118|[ERROR]|995|140615677372096|dlt|load.py|w_run_job:247|Transient exception in job transfomed_mvc_crashes.285db8faa3.csv in file /home/ksakra/.dlt/pipelines/dlt_ipykernel_launcher/load/normalized/1748229665.6249466/started_jobs/transfomed_mvc_crashes.285db8faa3.3.csv
# Traceback (most recent call last):
#   File "/mnt/d/Projects/Project-1-Motor-Vehicle-Collisions-/.venv/lib/python3.13/site-packages/dlt/common/destination/client.py", line 404, in run_managed
#     self.run()
#     ~~~~~~~~^^
#   File "/mnt/d/Projects/Project-1-Motor-Vehicle-Collisions-/.venv/lib/python3.13/site-packages/dlt/destinations/impl/postgres/postgres.py", line 133, in run
#     cursor.copy_expert(copy_sql, f, size=8192)
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
# psycopg2.errors.InvalidTextRepresentation: invalid input syntax for type double precision: "     "
# CONTEXT:  COPY transfomed_mvc_crashes, line 17724, column zip_code: "     "
#
# 2025-05-26 11:21:10,987|[WARNING]|995|140617910724416|dlt|load.py|complete_jobs:430|Job for transfomed_mvc_crashes.285db8faa3.csv retried in load 1748229665.6249466 with message invalid input syntax for type double precision: "     "
# CONTEXT:  COPY transfomed_mvc_crashes, line 17724, column zip_code: "     "
#
# 2025-05-26 11:21:11,127|[ERROR]|995|140615677372096|dlt|load.py|w_run_job:247|Transient exception in job transfomed_mvc_crashes.285db8faa3.csv in file /home/ksakra/.dlt/pipelines/dlt_ipykernel_launcher/load/normalized/1748229665.6249466/started_jobs/transfomed_mvc_crashes.285db8faa3.4.csv
# Traceback (most recent call last):
#   File "/mnt/d/Projects/Project-1-Motor-Vehicle-Collisions-/.venv/lib/python3.13/site-packages/dlt/common/destination/client.py", line 404, in run_managed
#     self.run()
#     ~~~~~~~~^^
#   File "/mnt/d/Projects/Project-1-Motor-Vehicle-Collisions-/.venv/lib/python3.13/site-packages/dlt/destinations/impl/postgres/postgres.py", line 133, in run
#     cursor.copy_expert(copy_sql, f, size=8192)
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
# psycopg2.errors.InvalidTextRepresentation: invalid input syntax for type double precision: "     "
# CONTEXT:  COPY transfomed_mvc_crashes, line 17724, column zip_code: "     "
#
# 2025-05-26 11:21:11,989|[WARNING]|995|140617910724416|dlt|load.py|complete_jobs:430|Job for transfomed_mvc_crashes.285db8faa3.csv retried in load 1748229665.6249466 with message invalid input syntax for type double precision: "     "
# CONTEXT:  COPY transfomed_mvc_crashes, line 17724, column zip_code: "     "
# ---------------------------------------------------------------------------
# LoadClientJobRetry                        Traceback (most recent call last)
# File /mnt/d/Projects/Project-1-Motor-Vehicle-Collisions-/.venv/lib/python3.13/site-packages/dlt/pipeline/pipeline.py:591, in Pipeline.load(self, destination, dataset_name, credentials, workers, raise_on_failed_jobs)
#     590 with signals.delayed_signals():
# --> 591     runner.run_pool(load_step.config, load_step)
#     592 info: LoadInfo = self._get_step_info(load_step)
#
# File /mnt/d/Projects/Project-1-Motor-Vehicle-Collisions-/.venv/lib/python3.13/site-packages/dlt/common/runners/pool_runner.py:91, in run_pool(config, run_f)
#      90 logger.debug("Running pool")
# ---> 91 while _run_func():
#      92     # for next run
#      93     signals.raise_if_signalled()
#
# File /mnt/d/Projects/Project-1-Motor-Vehicle-Collisions-/.venv/lib/python3.13/site-packages/dlt/common/runners/pool_runner.py:84, in run_pool.<locals>._run_func()
#      83 elif isinstance(run_f, Runnable):
# ---> 84     run_metrics = run_f.run(cast(TExecutor, pool))
#      85 else:
#
# File /mnt/d/Projects/Project-1-Motor-Vehicle-Collisions-/.venv/lib/python3.13/site-packages/dlt/load/load.py:638, in Load.run(self, pool)
#     637             self._step_info_start_load_id(load_id)
# --> 638         self.load_single_package(load_id, schema)
#     640 return TRunMetrics(False, len(self.load_storage.list_normalized_packages()))
#
# File /mnt/d/Projects/Project-1-Motor-Vehicle-Collisions-/.venv/lib/python3.13/site-packages/dlt/load/load.py:597, in Load.load_single_package(self, load_id, schema)
#     596 if pending_exception:
# --> 597     raise pending_exception
#     598 break
#
# LoadClientJobRetry: Job for transfomed_mvc_crashes.285db8faa3.csv had 5 retries which a multiple of 5. Exiting retry loop. You can still rerun the load package to retry this job. Last failure message was invalid input syntax for type double precision: "     "
# CONTEXT:  COPY transfomed_mvc_crashes, line 17724, column zip_code: "     "
#
#
# The above exception was the direct cause of the following exception:
#
# PipelineStepFailed                        Traceback (most recent call last)
# Cell In[13], line 8
#       6 for file in path.glob("*.csv"):
#       7     df = pd.read_csv(file)
# ----> 8     add_to_pipeline(df,name)
#
# Cell In[2], line 7, in add_to_pipeline(data, name)
#       4 pipeline = dlt.pipeline(destination="postgres", dataset_name="motor_vehicle_collisions")
#       6 # Run the pipeline
# ----> 7 load_info = pipeline.run(data,table_name=name, write_disposition="append", loader_file_format="csv")
#       9 # Print the load info
#      10 print(load_info)
#
# File /mnt/d/Projects/Project-1-Motor-Vehicle-Collisions-/.venv/lib/python3.13/site-packages/dlt/pipeline/pipeline.py:222, in with_runtime_trace.<locals>.decorator.<locals>._wrap(self, *args, **kwargs)
#     219     if trace:
#     220         trace_step = start_trace_step(trace, cast(TPipelineStep, f.__name__), self)
# --> 222     step_info = f(self, *args, **kwargs)
#     223     return step_info
#     224 except Exception as ex:
#
# File /mnt/d/Projects/Project-1-Motor-Vehicle-Collisions-/.venv/lib/python3.13/site-packages/dlt/pipeline/pipeline.py:271, in with_config_section.<locals>.decorator.<locals>._wrap(self, *args, **kwargs)
#     263 @wraps(f)
#     264 def _wrap(self: "Pipeline", *args: Any, **kwargs: Any) -> Any:
#     265     # add section context to the container to be used by all configuration without explicit sections resolution
#     266     with inject_section(
#     267         ConfigSectionContext(
#     268             pipeline_name=self.pipeline_name, sections=sections, merge_style=merge_func
#     269         )
#     270     ):
# --> 271         return f(self, *args, **kwargs)
#
# File /mnt/d/Projects/Project-1-Motor-Vehicle-Collisions-/.venv/lib/python3.13/site-packages/dlt/pipeline/pipeline.py:731, in Pipeline.run(self, data, destination, staging, dataset_name, credentials, table_name, write_disposition, columns, primary_key, schema, loader_file_format, table_format, schema_contract, refresh)
#     718     self.extract(
#     719         data,
#     720         table_name=table_name,
#    (...)    728         loader_file_format=loader_file_format,
#     729     )
#     730     self.normalize()
# --> 731     return self.load(destination, dataset_name, credentials=credentials)
#     732 else:
#     733     return None
#
# File /mnt/d/Projects/Project-1-Motor-Vehicle-Collisions-/.venv/lib/python3.13/site-packages/dlt/pipeline/pipeline.py:222, in with_runtime_trace.<locals>.decorator.<locals>._wrap(self, *args, **kwargs)
#     219     if trace:
#     220         trace_step = start_trace_step(trace, cast(TPipelineStep, f.__name__), self)
# --> 222     step_info = f(self, *args, **kwargs)
#     223     return step_info
#     224 except Exception as ex:
#
# File /mnt/d/Projects/Project-1-Motor-Vehicle-Collisions-/.venv/lib/python3.13/site-packages/dlt/pipeline/pipeline.py:162, in with_state_sync.<locals>.decorator.<locals>._wrap(self, *args, **kwargs)
#     160 should_extract_state = may_extract_state and self.config.restore_from_destination
#     161 with self.managed_state(extract_state=should_extract_state):
# --> 162     return f(self, *args, **kwargs)
#
# File /mnt/d/Projects/Project-1-Motor-Vehicle-Collisions-/.venv/lib/python3.13/site-packages/dlt/pipeline/pipeline.py:271, in with_config_section.<locals>.decorator.<locals>._wrap(self, *args, **kwargs)
#     263 @wraps(f)
#     264 def _wrap(self: "Pipeline", *args: Any, **kwargs: Any) -> Any:
#     265     # add section context to the container to be used by all configuration without explicit sections resolution
#     266     with inject_section(
#     267         ConfigSectionContext(
#     268             pipeline_name=self.pipeline_name, sections=sections, merge_style=merge_func
#     269         )
#     270     ):
# --> 271         return f(self, *args, **kwargs)
#
# File /mnt/d/Projects/Project-1-Motor-Vehicle-Collisions-/.venv/lib/python3.13/site-packages/dlt/pipeline/pipeline.py:598, in Pipeline.load(self, destination, dataset_name, credentials, workers, raise_on_failed_jobs)
#     596 except Exception as l_ex:
#     597     step_info = self._get_step_info(load_step)
# --> 598     raise PipelineStepFailed(
#     599         self, "load", load_step.current_load_id, l_ex, step_info
#     600     ) from l_ex
#
# PipelineStepFailed: Pipeline execution failed at stage load when processing package 1748229665.6249466 with exception:
#
# <class 'dlt.load.exceptions.LoadClientJobRetry'>
# Job for transfomed_mvc_crashes.285db8faa3.csv had 5 retries which a multiple of 5. Exiting retry loop. You can still rerun the load package to retry this job. Last failure message was invalid input syntax for type double precision: "     "
# CONTEXT:  COPY transfomed_mvc_crashes, line 17724, column zip_code: "     "
