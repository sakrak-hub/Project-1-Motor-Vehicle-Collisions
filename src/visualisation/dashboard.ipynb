# %%
# %load_ext autoreload
# %autoreload 2
import os
import sys
module_path = os.path.abspath(os.path.join('/mnt/d/Projects/Project-1-Motor-Vehicle-Collisions-/src'))
sys.path.insert(0, module_path)
os.chdir("/mnt/d/Projects/Project-1-Motor-Vehicle-Collisions-")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import streamlit as st
import pandas as pd
# from dlt.secrets
from sqlalchemy import create_engine
import plotly.express as px
import plotly.graph_objects as go

# %%
conn = create_engine('postgresql+psycopg2://loader:pipeloader@localhost:5432/dlt_data')

# %%
query = """SELECT
DATE_TRUNC('month', crash_date)::DATE AS crash_month,
SUM(number_of_persons_injured) AS total_injury,
SUM(number_of_persons_killed) AS total_killed
FROM motor_vehicle_collisions.mvc_crashes_silver
GROUP BY 1
ORDER BY 1;"""
df = pd.read_sql(query, conn)
df
# Out:
#     crash_month  total_injury  total_killed
# 0    2012-07-01          4891            15
# 1    2012-08-01          5042            38
# 2    2012-09-01          4683            30
# 3    2012-10-01          4276            16
# 4    2012-11-01          4113            17
# ..          ...           ...           ...
# 150  2025-01-01          3475            14
# 151  2025-02-01          3758            25
# 152  2025-03-01          3785            12
# 153  2025-04-01          3976            13
# 154  2025-05-01          3206            12
#
# [155 rows x 3 columns]

# %%
st.set_page_config(layout="wide")
# Out:
# 2025-06-12 16:17:46.929 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-12 16:17:46.930 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-12 16:17:46.931 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-12 16:17:46.931 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
import json

# %%
with open('/mnt/d/Projects/Project-1-Motor-Vehicle-Collisions-/src/visualisation/Borough Boundaries_20250615.geojson') as f:
    borough_geojson = json.load(f)

# %%
for feature in borough_geojson["features"]:
    boroname = feature["properties"]["boroname"].title()
    print(boroname)
# Out:
# Staten Island
# Brooklyn
# Queens
# Manhattan
# Bronx

# %%
borough_geojson
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'borocode': '5',
#     'boroname': 'Staten Island',
#     'shape_area': '1623618358.46',
#     'shape_leng': '325912.288988'},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-74.05050806403247, 40.56642203416086],
#        [-74.05047137128506, 40.566417387435564],
#        [-74.05030321271722, 40.566417461200594],
#        [-74.05012587375454, 40.56640588033513],
#        [-74.04998352562573, 40.566395924928315],
#        [-74.04931640362085, 40.56588774778048],
#        [-74.04923629842045, 40.565362736368144],
#        [-74.05002620158642, 40.565318180621176],
#        [-74.05074409977213, 40.56588712593507],
#        [-74.05074768943298, 40.56595407675391],
#        [-74.05073223954238, 40.565992119017764],
#        [-74.05073571037052, 40.566032774595826],
#        [-74.05080326895582, 40.566052200461186],
#        [-74.05087333045633, 40.566081240209904],
# ...
